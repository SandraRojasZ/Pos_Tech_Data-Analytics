# %% [markdown]
# # Analisando dados de produção hospitalar

# %% [markdown]
# ### 1.2

# %%
import pandas as pd

# %%
# dados é um DataFrame
dados = pd.read_csv("/content/dadoshospitalar.csv", encoding="ISO-8859-1",
            skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
# Out:
# <ipython-input-2-40b612a38b10>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv("/content/dadoshospitalar.csv", encoding="ISO-8859-1",

# %%
dados.head()
# Out:
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528.39   2931283.42   1541682.52   1525314.96
# 1              12 Acre    902416.00   1497206.26   1794028.48   1730469.42
# 2          13 Amazonas   4735529.42   7118990.57   8196635.49   8259378.42
# 3           14 Roraima    657889.53    777939.31    718688.03    839994.39
# 4              15 Pará  18864744.11  19553758.20  21937342.70  20842829.69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 0   1645953.84   1406150.68   3065279.01   3231494.61   3117178.63  ...
# 1   1819443.92   1828496.00   2511754.59   2089107.14   2275708.53  ...
# 2   7831399.90   8477273.62   9368858.72   9352532.70   9363099.35  ...
# 3    862347.96    832440.66    996693.09    894271.18    910424.17  ...
# 4  23249952.88  23240687.56  24002223.56  23341218.03  25172261.32  ...
#
#       2023/Out     2023/Nov     2023/Dez     2024/Jan     2024/Fev  \
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 22   43 Rio Grande do Sul  30931325.46  57363420.01  51547794.07  56673338.49
# 23  50 Mato Grosso do Sul   5377392.11   7002472.61   8423933.19   8797487.68
# 24         51 Mato Grosso   4795299.01   8684882.23   7886243.14   8794109.79
# 25               52 Goiás  15310637.29  22258668.68  21442515.75  20921212.45
# 26    53 Distrito Federal   4745919.19   7632480.67   9647203.26  11098732.99
#
#        2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 22  48397733.07  52413429.62  56636376.98  56113054.70  55356224.30  ...
# 23   9770421.80  10905392.18  10249299.82   9671553.45  10218511.05  ...
# 24   9231645.40  10221763.77   9163314.28   9243148.81   9052354.89  ...
# 25  21615970.67  18270043.87  20540517.13  20650730.67  20868443.56  ...
# 26  12891719.72  12850125.67  12565646.74  13710857.89  13165106.20  ...
#
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 200 entries, Unidade da Federação to Total
# dtypes: float64(198), object(2)
# memory usage: 42.3+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean(numeric_only=True)
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2024/Mar     70797784.92
# 2024/Abr     72218520.27
# 2024/Mai     72584793.40
# 2024/Jun     70181204.76
# Total      8933463602.22
# Length: 198, dtype: float64

# %% [markdown]
# ### 1.3

# %%
dados["2008/Ago"]
# Out:
# 0      3231494.61
# 1      2089107.14
# 2      9352532.70
# 3       894271.18
# 4     23341218.03
# 5      1475551.38
# 6      5413710.38
# 7     15195312.89
# 8     10549176.40
# 9     27851438.72
# 10    10640817.47
# 11    12872578.37
# 12    35457038.66
# 13     9373432.00
# 14     5238398.50
# 15    46931248.28
# 16    84722528.10
# 17    12588595.77
# 18    50912706.60
# 19   184854516.35
# 20    56982774.90
# 21    31250854.33
# 22    56113054.70
# 23     9671553.45
# 24     9243148.81
# 25    20650730.67
# 26    13710857.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

axis = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")

# Não faz retornar nenhum comentário, apenas o gráfico na "tela"
plt.show()

# %% [markdown]
# Desafio 1: executar o gráfico anterior com o mês mais recente

# %%
coluna_recente = dados.columns[-2]

# %%
coluna_recente
# Out:
# '2024/Jun'

# %% [markdown]
# Desafio 2: deixar as legendas ânguladas (0, 45 etc) para facilitar a leitura

# %%
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
axis = dados.plot(x="Unidade da Federação", y = coluna_recente, kind="bar", figsize=(20,8))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.xticks(rotation=45)
plt.title("Valor por Unidade da Federação")
plt.show()

# %% [markdown]
# 2.1

# %%
mes_8 = dados.columns[8]
mes_9 = dados.columns[9]

# %%
#dados[["2008/Ago", "2008/Set"]].head()
dados[[mes_8, mes_9]].head()
# Out:
#      2008/Ago    2008/Set
# 0  3231494.61  3117178.63
# 1  2089107.14  2275708.53
# 2  9352532.70  9363099.35
# 3   894271.18   910424.17
# 4 23341218.03 25172261.32

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '2008/Jan', '2008/Fev', '2008/Mar', '2008/Abr',
#        '2008/Mai', '2008/Jun', '2008/Jul', '2008/Ago', '2008/Set',
#        ...
#        '2023/Out', '2023/Nov', '2023/Dez', '2024/Jan', '2024/Fev', '2024/Mar',
#        '2024/Abr', '2024/Mai', '2024/Jun', 'Total'],
#       dtype='object', length=200)

# %%
colunas_usaveis = dados.mean(numeric_only=True).index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis[:5]
# Out:
# ['Unidade da Federação', '2008/Jan', '2008/Fev', '2008/Mar', '2008/Abr']

# %%
dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação    2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# 0          11 Rondônia  1388528.39  2931283.42  1541682.52  1525314.96
# 1              12 Acre   902416.00  1497206.26  1794028.48  1730469.42
# 2          13 Amazonas  4735529.42  7118990.57  8196635.49  8259378.42
# 3           14 Roraima   657889.53   777939.31   718688.03   839994.39
# 4              15 Pará 18864744.11 19553758.20 21937342.70 20842829.69
#
#      2008/Mai    2008/Jun    2008/Jul    2008/Ago    2008/Set  ...  \
# 0  1645953.84  1406150.68  3065279.01  3231494.61  3117178.63  ...
# 1  1819443.92  1828496.00  2511754.59  2089107.14  2275708.53  ...
# 2  7831399.90  8477273.62  9368858.72  9352532.70  9363099.35  ...
# 3   862347.96   832440.66   996693.09   894271.18   910424.17  ...
# 4 23249952.88 23240687.56 24002223.56 23341218.03 25172261.32  ...
#
#      2023/Out    2023/Nov    2023/Dez    2024/Jan    2024/Fev    2024/Mar  \
# ...

# %%
# Transformando uma coluna em índice
dados_usaveis = dados_usaveis.set_index("Unidade da Federação")
dados_usaveis.head()
# Out:
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1388528.39  2931283.42  1541682.52  1525314.96
# 12 Acre                902416.00  1497206.26  1794028.48  1730469.42
# 13 Amazonas           4735529.42  7118990.57  8196635.49  8259378.42
# 14 Roraima             657889.53   777939.31   718688.03   839994.39
# 15 Pará              18864744.11 19553758.20 21937342.70 20842829.69
#
#                         2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 11 Rondônia           1645953.84  1406150.68  3065279.01  3231494.61
# 12 Acre               1819443.92  1828496.00  2511754.59  2089107.14
# 13 Amazonas           7831399.90  8477273.62  9368858.72  9352532.70
# 14 Roraima             862347.96   832440.66   996693.09   894271.18
# 15 Pará              23249952.88 23240687.56 24002223.56 23341218.03
#
#                         2008/Set    2008/Out  ...    2023/Out    2023/Nov  \
# ...

# %%
dados_usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    9170787.53
# 12 Acre        3204998.88
# 13 Amazonas   15787896.78
# 14 Roraima     3788154.80
# 15 Pará       31179893.86
# Name: 2019/Ago, dtype: float64

# %%
# loc: localiza | loc pela chave
# Utiliza os rótulos (nomes) das linhas e colunas para realizar a seleção.
dados_usaveis.loc["12 Acre"]
# Out:
# 2008/Jan      902416.00
# 2008/Fev     1497206.26
# 2008/Mar     1794028.48
# 2008/Abr     1730469.42
# 2008/Mai     1819443.92
#                ...
# 2024/Mar     4819515.84
# 2024/Abr     5560094.15
# 2024/Mai     4374108.09
# 2024/Jun     4484207.99
# Total      615416604.48
# Name: 12 Acre, Length: 198, dtype: float64

# %%
# Baseado em índices numéricos: Utiliza os índices numéricos das linhas e colunas (iniciando em 0) para realizar a seleção.
# Não inclui o último elemento
dados_usaveis.iloc[1]
# Out:
# 2008/Jan      902416.00
# 2008/Fev     1497206.26
# 2008/Mar     1794028.48
# 2008/Abr     1730469.42
# 2008/Mai     1819443.92
#                ...
# 2024/Mar     4819515.84
# 2024/Abr     5560094.15
# 2024/Mai     4374108.09
# 2024/Jun     4484207.99
# Total      615416604.48
# Name: 12 Acre, Length: 198, dtype: float64

# %%
dados_usaveis.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
# Transposição
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  13 Amazonas  14 Roraima  \
# 2008/Jan               1388528.39  902416.00   4735529.42   657889.53
# 2008/Fev               2931283.42 1497206.26   7118990.57   777939.31
# 2008/Mar               1541682.52 1794028.48   8196635.49   718688.03
# 2008/Abr               1525314.96 1730469.42   8259378.42   839994.39
# 2008/Mai               1645953.84 1819443.92   7831399.90   862347.96
#
# Unidade da Federação     15 Pará   16 Amapá  17 Tocantins  21 Maranhão  \
# 2008/Jan             18864744.11 1120973.34    3441592.69  10723506.39
# 2008/Fev             19553758.20 1268740.33    4985688.85  13559679.41
# 2008/Mar             21937342.70  974651.24    6205612.60  13985142.36
# 2008/Abr             20842829.69 1141137.32    4984482.09  14809416.46
# 2008/Mai             23249952.88  866346.18    5511002.46  14505727.38
#
# Unidade da Federação    22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2024/Mar               12578152.13   4819515.84   23350848.79   2654012.71
# 2024/Abr               11559993.57   5560094.15   23226650.33   2321224.13
# 2024/Mai               11828541.38   4374108.09   22959304.30   2548379.72
# 2024/Jun                1968819.10   4484207.99   21291999.69   2598375.67
# Total                1446704922.33 615416604.48 2728085655.80 467066312.33
#
# Unidade da Federação       15 Pará     16 Amapá  17 Tocantins   21 Maranhão  \
# 2024/Mar               53972497.56   3580261.72    9320543.87   45800973.94
# 2024/Abr               53473198.11   3880761.58   10713160.33   42785118.16
# 2024/Mai               52370302.43   4271287.44   10165573.82   42220107.38
# 2024/Jun               48365091.56   4114870.26   10774197.65   40953254.49
# Total                6589319524.97 454244659.82 1423360586.79 5464095395.44
#
# ...

# %%
# Eixos > 0 Linha | 1 Coluna
dados_usaveis = dados_usaveis.drop("Total", axis=1)
dados_usaveis.head()
# Out:
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1388528.39  2931283.42  1541682.52  1525314.96
# 12 Acre                902416.00  1497206.26  1794028.48  1730469.42
# 13 Amazonas           4735529.42  7118990.57  8196635.49  8259378.42
# 14 Roraima             657889.53   777939.31   718688.03   839994.39
# 15 Pará              18864744.11 19553758.20 21937342.70 20842829.69
#
#                         2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 11 Rondônia           1645953.84  1406150.68  3065279.01  3231494.61
# 12 Acre               1819443.92  1828496.00  2511754.59  2089107.14
# 13 Amazonas           7831399.90  8477273.62  9368858.72  9352532.70
# 14 Roraima             862347.96   832440.66   996693.09   894271.18
# 15 Pará              23249952.88 23240687.56 24002223.56 23341218.03
#
#                         2008/Set    2008/Out  ...    2023/Set    2023/Out  \
# ...

# %%
dados_usaveis.T.max()
# Out:
# Unidade da Federação
# 11 Rondônia               16492196.14
# 12 Acre                    6354514.15
# 13 Amazonas               26903413.08
# 14 Roraima                 5171370.92
# 15 Pará                   56122128.80
# 16 Amapá                   6327228.14
# 17 Tocantins              11833522.68
# 21 Maranhão               53579187.88
# 22 Piauí                  31135971.40
# 23 Ceará                 110342286.04
# 24 Rio Grande do Norte    36887747.96
# 25 Paraíba                49394612.22
# 26 Pernambuco            125973975.41
# 27 Alagoas                29651474.26
# 28 Sergipe                19633473.10
# 29 Bahia                 133185386.00
# 31 Minas Gerais          268787737.44
# 32 Espírito Santo         56417132.95
# 33 Rio de Janeiro        137666323.83
# 35 São Paulo             527439291.73
# 41 Paraná                183043114.14
# 42 Santa Catarina        128398293.46
# 43 Rio Grande do Sul     153146292.86
# 50 Mato Grosso do Sul     36713343.08
# ...

# %% [markdown]
# Desafio: reposicionar a legenda. Dentro? Fora? Onde?

# %%
# Reposicionando a legenda Dentro do gráfico
dados_usaveis.T.plot(figsize=(12,6))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.95))

# %%
# Reposicionando a legenda Fora do gráfico
dados_usaveis.T.plot(figsize=(12,6))
# plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.95))
# Colocando a legenda fora do gráfico
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# Desafio: retocar título da nossa visualização
#
# Desafio: colocar títulos nos dois eixos
#
# ---

# %%
dados_usaveis.T.plot(figsize=(12,6))
plt.title("Unidade da Federação", fontsize=18, fontweight='bold', color='blue', loc='center', pad=20)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xlabel('Ano/Mês')  # Título do eixo x
plt.ylabel('Valor', color='b')  # Título do eixo y esquerdo

plt.show()

# %% [markdown]
# aula 3 | Parte 2

# %%
dados_usaveis.head()
# Out:
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1388528.39  2931283.42  1541682.52  1525314.96
# 12 Acre                902416.00  1497206.26  1794028.48  1730469.42
# 13 Amazonas           4735529.42  7118990.57  8196635.49  8259378.42
# 14 Roraima             657889.53   777939.31   718688.03   839994.39
# 15 Pará              18864744.11 19553758.20 21937342.70 20842829.69
#
#                         2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 11 Rondônia           1645953.84  1406150.68  3065279.01  3231494.61
# 12 Acre               1819443.92  1828496.00  2511754.59  2089107.14
# 13 Amazonas           7831399.90  8477273.62  9368858.72  9352532.70
# 14 Roraima             862347.96   832440.66   996693.09   894271.18
# 15 Pará              23249952.88 23240687.56 24002223.56 23341218.03
#
#                         2008/Set    2008/Out  ...    2023/Set    2023/Out  \
# ...

# %%
dados_usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis[:5]
# Out:
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1388528.39  2931283.42  1541682.52  1525314.96
# 12 Acre                902416.00  1497206.26  1794028.48  1730469.42
# 13 Amazonas           4735529.42  7118990.57  8196635.49  8259378.42
# 14 Roraima             657889.53   777939.31   718688.03   839994.39
# 15 Pará              18864744.11 19553758.20 21937342.70 20842829.69
#
#                         2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 11 Rondônia           1645953.84  1406150.68  3065279.01  3231494.61
# 12 Acre               1819443.92  1828496.00  2511754.59  2089107.14
# 13 Amazonas           7831399.90  8477273.62  9368858.72  9352532.70
# 14 Roraima             862347.96   832440.66   996693.09   894271.18
# 15 Pará              23249952.88 23240687.56 24002223.56 23341218.03
#
#                         2008/Set    2008/Out  ...    2023/Set    2023/Out  \
# ...

# %%
dados_usaveis[:7].T.plot(figsize=(10,6))
plt.title("Unidade da Federação", fontsize=18, fontweight='bold', color='blue', loc='center', pad=20)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xlabel('Ano/Mês')  # Título do eixo x
plt.ylabel('Valor', color='b')  # Título do eixo y esquerdo
# Out:
# Text(0, 0.5, 'Valor')

# %%
# Escolhendo uma amostra aleatória de 7 informações
dados_usaveis.sample(n=7)
# Out:
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 23 Ceará              15539821.90 25735101.55 28724625.75 30676457.06
# 41 Paraná             38266347.46 55384670.52 53801318.85 52460306.69
# 25 Paraíba            10723002.45 11386274.47 12053643.87 12653528.76
# 29 Bahia              21211522.47 28189304.95 34181483.52 39026934.13
# 50 Mato Grosso do Sul  5377392.11  7002472.61  8423933.19  8797487.68
# 28 Sergipe             2780750.11  3676483.16  5051473.61  5046063.36
# 12 Acre                 902416.00  1497206.26  1794028.48  1730469.42
#
#                          2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 23 Ceará              30604453.47 31272395.18 30925391.36 27851438.72
# 41 Paraná             54419620.71 57811688.48 58094241.83 56982774.90
# 25 Paraíba            12215107.11 12256928.49 12755413.77 12872578.37
# 29 Bahia              42949566.82 47025972.04 47481695.17 46931248.28
# ...

# %%
# Escolhendo uma amostra aleatória de 7 informações
dados_usaveis.sample(n=7).T.plot(figsize=(10,6))
plt.title("Unidade da Federação", fontsize=18, fontweight='bold', color='blue', loc='center', pad=20)
# Alocação da Legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xlabel('Ano/Mês', color='r')  # Título do eixo x
plt.ylabel('Valor', color='b')  # Título do eixo y esquerdo
# Out:
# Text(0, 0.5, 'Valor')

# %%
# pseudo aleatorio ... pseudo randomness
# semente == seed

import numpy as np

np.random.seed(524387)
dados_usaveis.sample(7)
# Out:
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 17 Tocantins          3441592.69  4985688.85  6205612.60  4984482.09
# 26 Pernambuco        14393949.89 24181400.95 29991302.71 34806197.97
# 31 Minas Gerais      45671659.76 70194037.10 79231336.95 77136537.58
# 22 Piauí              7985142.43 10079928.25 10298372.45 10775976.33
# 25 Paraíba           10723002.45 11386274.47 12053643.87 12653528.76
# 29 Bahia             21211522.47 28189304.95 34181483.52 39026934.13
# 42 Santa Catarina    16504913.45 25651429.11 26743524.89 27181488.26
#
#                         2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 17 Tocantins          5511002.46  4927934.22  5445602.28  5413710.38
# 26 Pernambuco        32147987.35 32239094.89 32685640.76 35457038.66
# 31 Minas Gerais      80554440.63 94758522.83 85360064.11 84722528.10
# 22 Piauí             10398360.88 10528253.88 11040107.92 10549176.40
# ...

# %%
dados_usaveis.sample(7).T.plot(figsize=(10,6))
plt.title("Unidade da Federação", fontsize=18, fontweight='bold', color='blue', loc='center', pad=20)
# Alocação da Legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xlabel('Ano/Mês', color='r')  # Título do eixo x
plt.ylabel('Valor', color='b')  # Título do eixo y esquerdo
# Out:
# Text(0, 0.5, 'Valor')

# %%
dados_usaveis["Total"] = dados_usaveis.sum(axis = 1)
dados_usaveis.head()
# Out:
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1388528.39  2931283.42  1541682.52  1525314.96
# 12 Acre                902416.00  1497206.26  1794028.48  1730469.42
# 13 Amazonas           4735529.42  7118990.57  8196635.49  8259378.42
# 14 Roraima             657889.53   777939.31   718688.03   839994.39
# 15 Pará              18864744.11 19553758.20 21937342.70 20842829.69
#
#                         2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 11 Rondônia           1645953.84  1406150.68  3065279.01  3231494.61
# 12 Acre               1819443.92  1828496.00  2511754.59  2089107.14
# 13 Amazonas           7831399.90  8477273.62  9368858.72  9352532.70
# 14 Roraima             862347.96   832440.66   996693.09   894271.18
# 15 Pará              23249952.88 23240687.56 24002223.56 23341218.03
#
#                         2008/Set    2008/Out  ...    2023/Out    2023/Nov  \
# ...

# %% [markdown]
# Dasafio: ordenar nosso Dataframe para que a primeira linha tenha a linha com maior gasto, e na última com menor gasto (ordenação)

# %%
dados_usaveis.sort_values(by='Total', ascending=False).head()
# Out:
#                         2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# Unidade da Federação
# 35 São Paulo         91678473.48 148677526.82 156087269.23 161227125.43
# 31 Minas Gerais      45671659.76  70194037.10  79231336.95  77136537.58
# 41 Paraná            38266347.46  55384670.52  53801318.85  52460306.69
# 43 Rio Grande do Sul 30931325.46  57363420.01  51547794.07  56673338.49
# 33 Rio de Janeiro    23025258.52  28394310.93  44567062.94  44054604.82
#
#                          2008/Mai     2008/Jun     2008/Jul     2008/Ago  \
# Unidade da Federação
# 35 São Paulo         187119397.64 187291126.07 194398399.48 184854516.35
# 31 Minas Gerais       80554440.63  94758522.83  85360064.11  84722528.10
# 41 Paraná             54419620.71  57811688.48  58094241.83  56982774.90
# 43 Rio Grande do Sul  48397733.07  52413429.62  56636376.98  56113054.70
# 33 Rio de Janeiro     44911021.15  48056212.24  49872379.35  50912706.60
#
# ...

# %% [markdown]
# Desafio: adicionar uma coluna com a região de cada estado

# %%
dados_usaveis.index
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
# Dicionário com o mapeamento de estados para regiões
regioes = {'11 Rondônia': 'Norte',
           '12 Acre': 'Norte',
           '13 Amazonas': 'Norte',
           '14 Roraima': 'Norte',
           '16 Amapá': 'Norte',
           '15 Pará': 'Norte',
           '17 Tocantins': 'Norte',
           '21 Maranhão': 'Nordeste',
           '22 Piauí': 'Nordeste',
           '23 Ceará': 'Nordeste',
           '26 Pernambuco': 'Nordeste',
           '24 Rio Grande do Norte': 'Nordeste',
           '25 Paraíba': 'Nordeste',
           '27 Alagoas': 'Nordeste',
           '28 Sergipe': 'Nordeste',
           '29 Bahia': 'Nordeste',
           '31 Minas Gerais': 'Sudeste',
           '32 Espírito Santo': 'Sudeste',
           '33 Rio de Janeiro': 'Sudeste',
           '35 São Paulo': 'Sudeste',
           '41 Paraná': 'Sul',
           '42 Santa Catarina': 'Sul',
           '43 Rio Grande do Sul': 'Sul',
           '50 Mato Grosso do Sul': 'Centro Oeste',
           '51 Mato Grosso': 'Centro Oeste',
           '52 Goiás' : 'Centro Oeste',
           '53 Distrito Federal': 'Centro Oeste'
           }

# %%
# Criando a nova coluna usando map()
dados_usaveis['Região'] = dados_usaveis.index.map(regioes)
dados_usaveis.tail()
# Out:
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 43 Rio Grande do Sul  30931325.46 57363420.01 51547794.07 56673338.49
# 50 Mato Grosso do Sul  5377392.11  7002472.61  8423933.19  8797487.68
# 51 Mato Grosso         4795299.01  8684882.23  7886243.14  8794109.79
# 52 Goiás              15310637.29 22258668.68 21442515.75 20921212.45
# 53 Distrito Federal    4745919.19  7632480.67  9647203.26 11098732.99
#
#                          2008/Mai    2008/Jun    2008/Jul    2008/Ago  \
# Unidade da Federação
# 43 Rio Grande do Sul  48397733.07 52413429.62 56636376.98 56113054.70
# 50 Mato Grosso do Sul  9770421.80 10905392.18 10249299.82  9671553.45
# 51 Mato Grosso         9231645.40 10221763.77  9163314.28  9243148.81
# 52 Goiás              21615970.67 18270043.87 20540517.13 20650730.67
# 53 Distrito Federal   12891719.72 12850125.67 12565646.74 13710857.89
#
# ...

# %% [markdown]
# Desafio: adicione seu estado nessa lista de 7 estados (dados_dos_7_estados)

# %%
dados_usaveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, 11 Rondônia to 53 Distrito Federal
# Columns: 199 entries, 2008/Jan to Região
# dtypes: float64(198), object(1)
# memory usage: 43.2+ KB

# %%
dados_usaveis.sample(7)
# Out:
#                         2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# Unidade da Federação
# 13 Amazonas           4735529.42   7118990.57   8196635.49   8259378.42
# 27 Alagoas            6243726.32   8376622.16   8408336.22   9090794.82
# 23 Ceará             15539821.90  25735101.55  28724625.75  30676457.06
# 53 Distrito Federal   4745919.19   7632480.67   9647203.26  11098732.99
# 32 Espírito Santo     5456723.98   9102212.86  10249595.97  11253833.56
# 35 São Paulo         91678473.48 148677526.82 156087269.23 161227125.43
# 51 Mato Grosso        4795299.01   8684882.23   7886243.14   8794109.79
#
#                          2008/Mai     2008/Jun     2008/Jul     2008/Ago  \
# Unidade da Federação
# 13 Amazonas            7831399.90   8477273.62   9368858.72   9352532.70
# 27 Alagoas             9338771.45  10068210.08   9887061.61   9373432.00
# 23 Ceará              30604453.47  31272395.18  30925391.36  27851438.72
# ...

# %%
# Eixos > 0 Linha | 1 Coluna
dados_usaveis = dados_usaveis.drop("Total", axis=1)

# %%
axis = dados_usaveis.select_dtypes(include='number').sample(7).T.plot(figsize=(10,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Unidade da Federação", fontsize=18, fontweight='bold', color='blue', loc='center', pad=20)
# Alocação da Legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xlabel('Ano/Mês', color='r')  # Título do eixo x
plt.ylabel('Valor', color='b')  # Título do eixo y esquerdo
# Out:
# Text(0, 0.5, 'Valor')

# %%
# Supondo que você queira as colunas a partir da 6ª (índice 5) até o final
colunas_a_partir_da_sexta = dados_usaveis.iloc[:, 5:]
#  7 Dados aleatório e apenas números
dados_amostra = colunas_a_partir_da_sexta.select_dtypes(include='number').sample(7)

dados_amostra = dados_amostra / 1_000_000

# %%
#dados_usaveis[6:].select_dtypes(include='number').sample(7).T.plot(figsize=(10,6))
axisU = dados_amostra.T.plot(figsize=(10,6))
# axisU.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Unidade da Federação", fontsize=18, fontweight='bold', color='blue', loc='center', pad=20)
# Alocação da Legenda
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xlabel('Ano/Mês', color='r')  # Título do eixo x
plt.ylabel('Gasto Aprovado em Milhões de Reais', color='b')  # Título do eixo y esquerdo
# Out:
# Text(0, 0.5, 'Gasto Aprovado em Milhões de Reais')

# %% [markdown]
# Desafio 1: Deixar o gráfico mais refinado

# %% [markdown]
# Desafio 2: pesquisar o sort_index
#
# ---

# %%
meses_filtrados = colunas_a_partir_da_sexta.columns[47:]

colunas_valor_M = colunas_a_partir_da_sexta[meses_filtrados].select_dtypes(include='number')
colunas_valor_D = colunas_valor_M / 1_000_000
colunas_valor_D = colunas_valor_D.head(3)

# %%
colunas_valor_D.T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
def plota_gastos_por_mes(dados, figsize=(10,6)):
  # Transpor os dados para ter os meses como colunas
  axis = dados.T.plot(figsize=figsize)
  #axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
  axis.set_ylabel("gasto aprovado em milhões de reais")
  axis.set_xlabel("mês/ano")

# %%
plota_gastos_por_mes(colunas_valor_D.head(3), figsize=(6,6))
plt.ylim(0, 40)
# Out:
# (0.0, 40.0)

# %%
plota_gastos_por_mes(colunas_valor_D.head(3), figsize=(20,6))
plt.ylim(0, 40)
# Out:
# (0.0, 40.0)

# %% [markdown]
# Desafio: Padronizar os ticks verticais para espaçamento de 12 em 12 unidades (uma vez ao ano)

# %% [markdown]
# Desafio 2: escolher e utilizar outras cores para saltar mais aos olhos

# %% [markdown]
# Desafio 3: colocar uma grade (grid) horizontal e vertical que não seja intrusivo
